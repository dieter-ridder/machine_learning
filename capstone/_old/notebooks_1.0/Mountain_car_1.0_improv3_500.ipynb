# %% [markdown]
# ##### Tiling 888, Improvement by decreasing gamma - 500 Episodes #
#
# Best version was already fast, but not fast enough. Next try is with bigger alpha in the beginning
#
# parameters:
#
# alpha:
#         if episode < 20:
#             return 0.65
#         else:
#             return 0.5
#
# gamma:
#         max(1.0-episode/200, 0.2)
#
# epsilon:
#         max(0.1-episode/200, 0.001)

# %%
import gym
import os
import numpy as np
os.environ["DISPLAY"] = ":0"

nbEpisodes=1
nbTimesteps=50
env = gym.make('MountainCar-v0')

class tileModel:
    def __init__(self, nbTilings, gridSize):
        # characteristica of observation
        self.obsHigh = env.observation_space.high
        self.obsLow = env.observation_space.low
        self.obsDim = len(self.obsHigh)
        
        # characteristica of tile model
        self.nbTilings = nbTilings
        self.gridSize = gridSize
        self.gridWidth = np.divide(np.subtract(self.obsHigh,self.obsLow), self.gridSize)
        self.nbTiles = (self.gridSize**self.obsDim) * self.nbTilings
        self.nbTilesExtra = (self.gridSize**self.obsDim) * (self.nbTilings+1)
        
        #state space
        self.nbActions = env.action_space.n
        self.resetStates()
        
    def resetStates(self):
        ### funktioniert nicht, auch nicht mit -10 self.states = np.random.uniform(low=10.5, high=-11.0, size=(self.nbTilesExtra,self.nbActions))
        self.states = np.random.uniform(low=0.0, high=0.0001, size=(self.nbTilesExtra,self.nbActions))
        ### self.states = np.zeros([self.nbTiles,self.nbActions])
        
        
    def displayM(self):
        print('observation:\thigh:', self.obsHigh, 'low:', self.obsLow, 'dim:',self.obsDim )
        print('tile model:\tnbTilings:', self.nbTilings, 'gridSize:',self.gridSize, 'gridWidth:',self.gridWidth,'nb tiles:', self.nbTiles )
        print('state space:\tnb of actions:', self.nbActions, 'size of state space:', self.nbTiles)
        
    def code (self, obsOrig):
        #shift the original observation to range [0, obsHigh-obsLow]
        #scale it to the external grid size: if grid is 8*8, each range is [0,8]
        obsScaled = np.divide(np.subtract(obsOrig,self.obsLow),self.gridWidth)
        ### print ('\noriginal obs:',obsOrig,'shifted and scaled obs:', obsScaled )
        
        #compute the coordinates/tiling
        #each tiling is shifted by tiling/gridSize, i.e. tiling*1/8 for grid 8*8
        #and casted to integer
        coordinates = np.zeros([self.nbTilings,self.obsDim])
        tileIndices = np.zeros(self.nbTilings)
        for tiling in range(self.nbTilings):
            coordinates[tiling,:] = obsScaled + tiling/ self.nbTilings
        coordinates=np.floor(coordinates)
        
        #this coordinates should be used to adress a 1-dimensional status array
        #for 8 tilings of 8*8 grid we use:
        #for tiling 0: 0-63, for tiling 1: 64-127,...
        coordinatesOrg=np.array(coordinates, copy=True)        
        ### print ('coordinates:', coordinates)
        
        for dim in range(1,self.obsDim):
            coordinates[:,dim] *= self.gridSize**dim
        ### print ('coordinates:', coordinates)
        condTrace=False
        for tiling in range(self.nbTilings):
            tileIndices[tiling] = (tiling * (self.gridSize**self.obsDim) \
                                   + sum(coordinates[tiling,:])) 
            if tileIndices[tiling] >= self.nbTilesExtra:
                condTrace=True
                
        if condTrace:
            print("code: obsOrig:",obsOrig, 'obsScaled:', obsScaled, "coordinates w/o shift:\n", coordinatesOrg )
            print ("coordinates multiplied with base:\n", coordinates, "\ntileIndices:", tileIndices)
        ### print ('tileIndices:', tileIndices)
        ### print ('coordinates-org:', coordinatesOrg)
        return coordinatesOrg, tileIndices
    
    def getQ(self,state):
        Q=np.zeros(self.nbActions)
        _,tileIndices=self.code(state)
        ### print ('getQ-in : state',state,'tileIndices:', tileIndices)

        for i in range(len(tileIndices)):
            index=int(tileIndices[i])
            Q=np.add(Q,self.states[index])
        ### print ('getQ-out : Q',Q)
        Q=np.divide(Q,self.nbTilings)
        return Q
    
    def updateQ(self, state, action, deltaQA):
        _,tileIndices=self.code(state)
        ### print ('updateQ-in : state',state,'tileIndices:', tileIndices,'action:', action, 'deltaQA:', deltaQA)

        for i in range(len(tileIndices)):
            index=int(tileIndices[i])
            self.states[index,action]+=deltaQA
            ### print ('updateQ: index:', index, 'states[index]:',self.states[index])
            
    def preparePlot(self):
        plotInput=np.zeros([self.gridSize*self.nbTilings, self.gridSize*self.nbTilings,self.nbActions])    #pos*velo*actions
        iTiling=0
        iDim1=0                 #velocity
        iDim0=0                 #position
        ### tileShift=1/self.nbTilings
        
        for i in range(self.nbTiles):
            ### print ('i:',i,'iTiling:',iTiling,'iDim0:',iDim0, 'iDim1:', iDim1 ,'state:', self.states[i])
            for jDim0 in range(iDim0*self.nbTilings-iTiling, (iDim0+1)*self.nbTilings-iTiling):
                for jDim1 in range(iDim1*self.nbTilings-iTiling, (iDim1+1)*self.nbTilings-iTiling):
                    ### print ('iTiling:',iTiling,'jDim0:', jDim0, 'jDim1:', jDim1, 'state before:', plotInput[jDim0,jDim1] )
                    if jDim0>0 and jDim1 >0:
                        plotInput[jDim0,jDim1]+=self.states[i]
                        ### print ('iTiling:',iTiling,'jDim0:', jDim0, 'jDim1:', jDim1, 'state after:', plotInput[jDim0,jDim1] )
            iDim0+=1
            if iDim0 >= self.gridSize:
                iDim1 +=1
                iDim0 =0
            if iDim1 >= self.gridSize:
                iTiling +=1
                iDim0=0
                iDim1=0
        return plotInput
# Out:
# [2017-05-31 23:35:55,630] Making new env: MountainCar-v0

# %%
tileModel  = tileModel(8,8)                     #grid: 8*8, 8 tilings
tileModel.displayM()
# Out:
# observation:	high: [ 0.6   0.07] low: [-1.2  -0.07] dim: 2
# tile model:	nbTilings: 8 gridSize: 8 gridWidth: [ 0.225   0.0175] nb tiles: 512
# state space:	nb of actions: 3 size of state space: 512

# %%
nbEpisodes = 10000
nbTimesteps = 200
alpha = 0.5
gamma = 1.0
epsilon = 0.01
EpisodesEvaluated=100
rewardLimit=-110

strategyEpsilon=4           #0: 1/episode**2, 1:1/episode, 2: (1/2)**episode 3: 0.01 4: linear 9:0.1
IntervalEpsilon=200
BaseEpsilon=0.05
StartEpsilon=0.1

strategyGamma=4
IntervalGamma=500
BaseGamma=0.2

strategyAlpha=6

policySARSA=True
printEpisodeResult=False

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random as random
### from matplotlib import colors as mcolors
### colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

def policy(Q,epsilon):    
    if epsilon>0.0 and random.random() < epsilon:
        return env.action_space.sample()
    else: 
        return np.argmax(Q) 

def decayFunction(episode, strategy=0, decayInterval=100, decayBase=0.5, decayStart=1.0):
    global nbEpisodes
    if strategy==0:
        return 1/((episode+1)**2)
    elif strategy ==1:
        return 1/(episode+1)
    elif strategy ==2:
        return (0.5)**episode
    elif strategy ==3:
        return 0.05
    elif strategy ==4:
        return max(decayStart-episode/decayInterval, decayBase)
    elif strategy ==5:
        return 0.5*(0.5**episode)+0.5
    elif strategy ==6:
        if episode < 20:
            return 0.5
        elif episode < 100:
            return 0.25
        else:
            return 0.1
    else:
        return 0.1

lastDelta=-1000.0
colorplot=np.empty([tileModel.nbTilings*tileModel.gridSize,tileModel.nbTilings*tileModel.gridSize],dtype=str)
tileModel.resetStates()
arrivedNb=0
arrivedFirst=0

rewardTracker = np.zeros(EpisodesEvaluated)
rewardAverages=[]
problemSolved=False
rewardMin=-200
averageMin=-200


for episode in range(nbEpisodes):                    
    state = env.reset()
    rewardAccumulated =0
    epsilon=decayFunction(episode,strategy=strategyEpsilon,\
                          decayInterval=IntervalEpsilon, decayBase=BaseEpsilon,decayStart=StartEpsilon)
    #gamma=decayFunction(episode,strategy=strategyGamma,decayInterval=IntervalGamma, decayBase=BaseGamma)
    alpha=decayFunction(episode,strategy=strategyAlpha)
    

    Q=tileModel.getQ(state)
    action = policy(Q,epsilon)
    ### print ('Q_all:', Q, 'action:', action, 'Q_action:',Q[action])

    deltaQAs=[0.0]
   
    for t in range(nbTimesteps):
        env.render()
        state_next, reward, done, info = env.step(action)
        rewardAccumulated+=reward
        ### print('\n--- step action:',action,'returns: reward:', reward, 'state_next:', state_next)
        if done:
            rewardTracker[episode%EpisodesEvaluated]=rewardAccumulated
            if episode>=EpisodesEvaluated:
                rewardAverage=np.mean(rewardTracker)
                if rewardAverage>=rewardLimit:
                    problemSolved=True
            else:
                rewardAverage=np.mean(rewardTracker[0:episode+1])
            rewardAverages.append(rewardAverage)
            
            if rewardAccumulated>rewardMin:
                rewardMin=rewardAccumulated
            if rewardAverage>averageMin:
                averageMin = rewardAverage
                
            print("Episode {} done after {} steps, reward Average: {}, up to now: minReward: {}, minAverage: {}"\
                  .format(episode, t+1, rewardAverage, rewardMin, averageMin))
            if t<nbTimesteps-1:
                ### print ("ARRIVED!!!!")
                arrivedNb+=1
                if arrivedFirst==0:
                    arrivedFirst=episode
            break
        #update Q(S,A)-Table according to:
        #Q(S,A) <- Q(S,A) + α (R + γ Q(S’, A’) – Q(S,A))
        
        #start with the information from the old state:
        #difference between Q(S,a) and actual reward
        #problem: reward belongs to state as whole (-1 for mountain car), Q[action] is the sum over several features
            
        #now we choose the next state/action pair:
        Q_next=tileModel.getQ(state_next)
        action_next=policy(Q_next,epsilon)
        action_QL=policy(Q_next,0.0)   

        if policySARSA:
            action_next_learning=action_next
        else:
            action_next_learning=action_QL

        
        # take into account the value of the next (Q(S',A') and update the tile model
        deltaQA=alpha*(reward + gamma * Q_next[action_next_learning] - Q[action])
        deltaQAs.append(deltaQA)
        
        ### print ('Q:', Q, 'action:', action, 'Q[action]:', Q[action])
        ### print ('Q_next:', Q_next, 'action_next:', action_next, 'Q_next[action_next]:', Q_next[action_next])
        ### print ('deltaQA:',deltaQA)
        tileModel.updateQ(state, action, deltaQA)
        ### print ('after update: Q:',tileModel.getQ(state))

        
        
        ###if lastDelta * deltaQA < 0:           #vorzeichenwechsel
        ###    print ('deltaQA in:alpha:', alpha,'reward:',reward,'gamma:',gamma,'action_next:', action_next,\
        ###           'Q_next[action_next]:',Q_next[action_next],'action:',action,'Q[action]:', Q[action],'deltaQA out:',deltaQA)
        ###lastDelta=deltaQA
        
        # prepare next round:
        state=state_next
        action=action_next
        Q=Q_next
               
    if printEpisodeResult:
        #evaluation of episode: development of deltaQA
        fig = plt.figure()
        ax1 = fig.add_subplot(111)
        ax1.plot(range(len(deltaQAs)),deltaQAs,'-')
        ax1.set_title("after episode:  {} - development of deltaQA".format(episode))
        plt.show()

        #evaluation of episode: states
        plotInput=tileModel.preparePlot()
        ### print ('states:', tileModel.states)
        ### print ('plotInput:', plotInput)
    
        fig = plt.figure()
        ax2 = fig.add_subplot(111, projection='3d')
    
        x=range(tileModel.nbTilings*tileModel.gridSize)
        y=range(tileModel.nbTilings*tileModel.gridSize)
        yUnscaled=y*tileModel.gridWidth[0]+tileModel.obsLow[0]
        xUnscaled=x*tileModel.gridWidth[1]+tileModel.obsLow[1]


        colors=['r','b','g']
        labels=['back','neutral','forward']
        for i in range(tileModel.nbActions):
            ax2.plot_wireframe(xUnscaled,yUnscaled,plotInput[x,y,i],color=colors[i],label=labels[i])

        ax2.set_xlabel('velocity')
        ax2.set_ylabel('position')
        ax2.set_zlabel('action')
        ax2.set_title("after episode:  {}".format(episode))
        ax2.legend()
        plt.show()

        #colorplot=np.empty([tileModel.nbTilings*tileModel.gridSize,tileModel.nbTilings*tileModel.gridSize],dtype=str)
        minVal=np.zeros(3)
        minCoo=np.empty([3,2])
        maxVal=np.zeros(3)
        maxCoo=np.empty([3,2])
        for ix in x:
            for iy in y:
                if 0.0 <= np.sum(plotInput[ix,iy,:]) and np.sum(plotInput[ix,iy,:])<=0.003:
                    colorplot[ix,iy]='g'
                elif colorplot[ix,iy]=='g':
                    colorplot[ix,iy]='blue'
                else:
                    colorplot[ix,iy]='cyan'
                

        xUnscaled=np.linspace(tileModel.obsLow[0], tileModel.obsHigh[0], num=tileModel.nbTilings*tileModel.gridSize)
        yUnscaled=np.linspace(tileModel.obsLow[1], tileModel.obsHigh[1], num=tileModel.nbTilings*tileModel.gridSize)

        fig = plt.figure()
        ax3 = fig.add_subplot(111)
    
        for i in x:
            ax3.scatter([i]*len(x),y,c=colorplot[i,y],s=75, alpha=0.5)

        #ax3.set_xticklabels(xUnscaled)
        #ax3.set_yticklabels(yUnscaled)
        ax3.set_xlabel('velocity')
        ax3.set_ylabel('position')
        ax3.set_title("after episode:  {} visited".format(episode))
        plt.show()
        
        if problemSolved:
            break

print('final result: \n{} times arrived in {} episodes, first time in episode {}\nproblem solved?:{}'.format(arrivedNb,nbEpisodes,arrivedFirst,problemSolved))
#evaluation of episode: development of deltaQA
fig = plt.figure()
ax4 = fig.add_subplot(111)
ax4.plot(range(len(rewardAverages)),rewardAverages,'-')
ax4.set_title("development of rewardAverages")
plt.show()
# Out:
# Episode 0 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 1 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 2 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 3 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 4 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 5 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 6 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 7 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 8 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 9 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 10 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 11 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 12 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 13 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 14 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 15 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 16 done after 200 steps, reward Average: -200.0, up to now: minReward: -200, minAverage: -200
# Episode 17 done after 165 steps, reward Average: -198.05555555555554, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 18 done after 200 steps, reward Average: -198.1578947368421, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 19 done after 200 steps, reward Average: -198.25, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 20 done after 200 steps, reward Average: -198.33333333333334, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 21 done after 200 steps, reward Average: -198.4090909090909, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 22 done after 200 steps, reward Average: -198.47826086956522, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 23 done after 200 steps, reward Average: -198.54166666666666, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 24 done after 200 steps, reward Average: -198.6, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 25 done after 200 steps, reward Average: -198.65384615384616, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 26 done after 200 steps, reward Average: -198.7037037037037, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 27 done after 200 steps, reward Average: -198.75, up to now: minReward: -165.0, minAverage: -198.05555555555554
# Episode 28 done after 178 steps, reward Average: -198.0344827586207, up to now: minReward: -165.0, minAverage: -198.0344827586207
# Episode 29 done after 200 steps, reward Average: -198.1, up to now: minReward: -165.0, minAverage: -198.0344827586207
# Episode 30 done after 166 steps, reward Average: -197.06451612903226, up to now: minReward: -165.0, minAverage: -197.06451612903226
# Episode 31 done after 200 steps, reward Average: -197.15625, up to now: minReward: -165.0, minAverage: -197.06451612903226
# Episode 32 done after 200 steps, reward Average: -197.24242424242425, up to now: minReward: -165.0, minAverage: -197.06451612903226
# Episode 33 done after 199 steps, reward Average: -197.2941176470588, up to now: minReward: -165.0, minAverage: -197.06451612903226
# Episode 34 done after 162 steps, reward Average: -196.28571428571428, up to now: minReward: -162.0, minAverage: -196.28571428571428
# Episode 35 done after 200 steps, reward Average: -196.38888888888889, up to now: minReward: -162.0, minAverage: -196.28571428571428
# Episode 36 done after 200 steps, reward Average: -196.48648648648648, up to now: minReward: -162.0, minAverage: -196.28571428571428
# Episode 37 done after 200 steps, reward Average: -196.57894736842104, up to now: minReward: -162.0, minAverage: -196.28571428571428
# Episode 38 done after 200 steps, reward Average: -196.66666666666666, up to now: minReward: -162.0, minAverage: -196.28571428571428
# Episode 39 done after 200 steps, reward Average: -196.75, up to now: minReward: -162.0, minAverage: -196.28571428571428
# Episode 40 done after 165 steps, reward Average: -195.97560975609755, up to now: minReward: -162.0, minAverage: -195.97560975609755
# Episode 41 done after 200 steps, reward Average: -196.07142857142858, up to now: minReward: -162.0, minAverage: -195.97560975609755
# Episode 42 done after 160 steps, reward Average: -195.2325581395349, up to now: minReward: -160.0, minAverage: -195.2325581395349
# Episode 43 done after 200 steps, reward Average: -195.3409090909091, up to now: minReward: -160.0, minAverage: -195.2325581395349
# Episode 44 done after 200 steps, reward Average: -195.44444444444446, up to now: minReward: -160.0, minAverage: -195.2325581395349
# Episode 45 done after 200 steps, reward Average: -195.54347826086956, up to now: minReward: -160.0, minAverage: -195.2325581395349
# Episode 46 done after 200 steps, reward Average: -195.63829787234042, up to now: minReward: -160.0, minAverage: -195.2325581395349
# Episode 47 done after 179 steps, reward Average: -195.29166666666666, up to now: minReward: -160.0, minAverage: -195.2325581395349
# Episode 48 done after 159 steps, reward Average: -194.55102040816325, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 49 done after 200 steps, reward Average: -194.66, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 50 done after 200 steps, reward Average: -194.76470588235293, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 51 done after 200 steps, reward Average: -194.8653846153846, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 52 done after 200 steps, reward Average: -194.96226415094338, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 53 done after 200 steps, reward Average: -195.05555555555554, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 54 done after 200 steps, reward Average: -195.14545454545456, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 55 done after 200 steps, reward Average: -195.23214285714286, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 56 done after 200 steps, reward Average: -195.31578947368422, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 57 done after 196 steps, reward Average: -195.32758620689654, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 58 done after 200 steps, reward Average: -195.40677966101694, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 59 done after 200 steps, reward Average: -195.48333333333332, up to now: minReward: -159.0, minAverage: -194.55102040816325
# Episode 60 done after 153 steps, reward Average: -194.78688524590163, up to now: minReward: -153.0, minAverage: -194.55102040816325
# Episode 61 done after 162 steps, reward Average: -194.25806451612902, up to now: minReward: -153.0, minAverage: -194.25806451612902
# Episode 62 done after 200 steps, reward Average: -194.34920634920636, up to now: minReward: -153.0, minAverage: -194.25806451612902
# Episode 63 done after 200 steps, reward Average: -194.4375, up to now: minReward: -153.0, minAverage: -194.25806451612902
# Episode 64 done after 174 steps, reward Average: -194.12307692307692, up to now: minReward: -153.0, minAverage: -194.12307692307692
# Episode 65 done after 195 steps, reward Average: -194.13636363636363, up to now: minReward: -153.0, minAverage: -194.12307692307692
# Episode 66 done after 160 steps, reward Average: -193.62686567164178, up to now: minReward: -153.0, minAverage: -193.62686567164178
# Episode 67 done after 191 steps, reward Average: -193.58823529411765, up to now: minReward: -153.0, minAverage: -193.58823529411765
# Episode 68 done after 153 steps, reward Average: -193.0, up to now: minReward: -153.0, minAverage: -193.0
# Episode 69 done after 159 steps, reward Average: -192.5142857142857, up to now: minReward: -153.0, minAverage: -192.5142857142857
# Episode 70 done after 200 steps, reward Average: -192.61971830985917, up to now: minReward: -153.0, minAverage: -192.5142857142857
# Episode 71 done after 165 steps, reward Average: -192.23611111111111, up to now: minReward: -153.0, minAverage: -192.23611111111111
# Episode 72 done after 154 steps, reward Average: -191.7123287671233, up to now: minReward: -153.0, minAverage: -191.7123287671233
# Episode 73 done after 155 steps, reward Average: -191.21621621621622, up to now: minReward: -153.0, minAverage: -191.21621621621622
# Episode 74 done after 157 steps, reward Average: -190.76, up to now: minReward: -153.0, minAverage: -190.76
# Episode 75 done after 153 steps, reward Average: -190.26315789473685, up to now: minReward: -153.0, minAverage: -190.26315789473685
# Episode 76 done after 128 steps, reward Average: -189.45454545454547, up to now: minReward: -128.0, minAverage: -189.45454545454547
# Episode 77 done after 200 steps, reward Average: -189.5897435897436, up to now: minReward: -128.0, minAverage: -189.45454545454547
# Episode 78 done after 164 steps, reward Average: -189.26582278481013, up to now: minReward: -128.0, minAverage: -189.26582278481013
# Episode 79 done after 200 steps, reward Average: -189.4, up to now: minReward: -128.0, minAverage: -189.26582278481013
# Episode 80 done after 164 steps, reward Average: -189.08641975308643, up to now: minReward: -128.0, minAverage: -189.08641975308643
# Episode 81 done after 162 steps, reward Average: -188.7560975609756, up to now: minReward: -128.0, minAverage: -188.7560975609756
# Episode 82 done after 159 steps, reward Average: -188.3975903614458, up to now: minReward: -128.0, minAverage: -188.3975903614458
# Episode 83 done after 200 steps, reward Average: -188.53571428571428, up to now: minReward: -128.0, minAverage: -188.3975903614458
# Episode 84 done after 189 steps, reward Average: -188.54117647058823, up to now: minReward: -128.0, minAverage: -188.3975903614458
# Episode 85 done after 122 steps, reward Average: -187.7674418604651, up to now: minReward: -122.0, minAverage: -187.7674418604651
# Episode 86 done after 200 steps, reward Average: -187.90804597701148, up to now: minReward: -122.0, minAverage: -187.7674418604651
# Episode 87 done after 200 steps, reward Average: -188.04545454545453, up to now: minReward: -122.0, minAverage: -187.7674418604651
# Episode 88 done after 171 steps, reward Average: -187.85393258426967, up to now: minReward: -122.0, minAverage: -187.7674418604651
# Episode 89 done after 154 steps, reward Average: -187.4777777777778, up to now: minReward: -122.0, minAverage: -187.4777777777778
# Episode 90 done after 155 steps, reward Average: -187.12087912087912, up to now: minReward: -122.0, minAverage: -187.12087912087912
# Episode 91 done after 156 steps, reward Average: -186.7826086956522, up to now: minReward: -122.0, minAverage: -186.7826086956522
# Episode 92 done after 157 steps, reward Average: -186.46236559139786, up to now: minReward: -122.0, minAverage: -186.46236559139786
# Episode 93 done after 200 steps, reward Average: -186.60638297872342, up to now: minReward: -122.0, minAverage: -186.46236559139786
# Episode 94 done after 139 steps, reward Average: -186.10526315789474, up to now: minReward: -122.0, minAverage: -186.10526315789474
# Episode 95 done after 193 steps, reward Average: -186.17708333333334, up to now: minReward: -122.0, minAverage: -186.10526315789474
# Episode 96 done after 184 steps, reward Average: -186.15463917525773, up to now: minReward: -122.0, minAverage: -186.10526315789474
# Episode 97 done after 186 steps, reward Average: -186.1530612244898, up to now: minReward: -122.0, minAverage: -186.10526315789474
# Episode 98 done after 125 steps, reward Average: -185.53535353535352, up to now: minReward: -122.0, minAverage: -185.53535353535352
# Episode 99 done after 173 steps, reward Average: -185.41, up to now: minReward: -122.0, minAverage: -185.41
# Episode 100 done after 190 steps, reward Average: -185.31, up to now: minReward: -122.0, minAverage: -185.31
# Episode 101 done after 119 steps, reward Average: -184.5, up to now: minReward: -119.0, minAverage: -184.5
# Episode 102 done after 143 steps, reward Average: -183.93, up to now: minReward: -119.0, minAverage: -183.93
# Episode 103 done after 187 steps, reward Average: -183.8, up to now: minReward: -119.0, minAverage: -183.8
# Episode 104 done after 145 steps, reward Average: -183.25, up to now: minReward: -119.0, minAverage: -183.25
# Episode 105 done after 152 steps, reward Average: -182.77, up to now: minReward: -119.0, minAverage: -182.77
# Episode 106 done after 145 steps, reward Average: -182.22, up to now: minReward: -119.0, minAverage: -182.22
# Episode 107 done after 122 steps, reward Average: -181.44, up to now: minReward: -119.0, minAverage: -181.44
# Episode 108 done after 155 steps, reward Average: -180.99, up to now: minReward: -119.0, minAverage: -180.99
# Episode 109 done after 192 steps, reward Average: -180.91, up to now: minReward: -119.0, minAverage: -180.91
# Episode 110 done after 121 steps, reward Average: -180.12, up to now: minReward: -119.0, minAverage: -180.12
# Episode 111 done after 200 steps, reward Average: -180.12, up to now: minReward: -119.0, minAverage: -180.12
# Episode 112 done after 163 steps, reward Average: -179.75, up to now: minReward: -119.0, minAverage: -179.75
# Episode 113 done after 192 steps, reward Average: -179.67, up to now: minReward: -119.0, minAverage: -179.67
# Episode 114 done after 196 steps, reward Average: -179.63, up to now: minReward: -119.0, minAverage: -179.63
# Episode 115 done after 123 steps, reward Average: -178.86, up to now: minReward: -119.0, minAverage: -178.86
# Episode 116 done after 161 steps, reward Average: -178.47, up to now: minReward: -119.0, minAverage: -178.47
# Episode 117 done after 197 steps, reward Average: -178.79, up to now: minReward: -119.0, minAverage: -178.47
# Episode 118 done after 122 steps, reward Average: -178.01, up to now: minReward: -119.0, minAverage: -178.01
# Episode 119 done after 118 steps, reward Average: -177.19, up to now: minReward: -118.0, minAverage: -177.19
# Episode 120 done after 140 steps, reward Average: -176.59, up to now: minReward: -118.0, minAverage: -176.59
# Episode 121 done after 200 steps, reward Average: -176.59, up to now: minReward: -118.0, minAverage: -176.59
# Episode 122 done after 180 steps, reward Average: -176.39, up to now: minReward: -118.0, minAverage: -176.39
# Episode 123 done after 127 steps, reward Average: -175.66, up to now: minReward: -118.0, minAverage: -175.66
# Episode 124 done after 155 steps, reward Average: -175.21, up to now: minReward: -118.0, minAverage: -175.21
# Episode 125 done after 121 steps, reward Average: -174.42, up to now: minReward: -118.0, minAverage: -174.42
# Episode 126 done after 200 steps, reward Average: -174.42, up to now: minReward: -118.0, minAverage: -174.42
# Episode 127 done after 157 steps, reward Average: -173.99, up to now: minReward: -118.0, minAverage: -173.99
# Episode 128 done after 150 steps, reward Average: -173.71, up to now: minReward: -118.0, minAverage: -173.71
# Episode 129 done after 155 steps, reward Average: -173.26, up to now: minReward: -118.0, minAverage: -173.26
# Episode 130 done after 151 steps, reward Average: -173.11, up to now: minReward: -118.0, minAverage: -173.11
# Episode 131 done after 145 steps, reward Average: -172.56, up to now: minReward: -118.0, minAverage: -172.56
# Episode 132 done after 154 steps, reward Average: -172.1, up to now: minReward: -118.0, minAverage: -172.1
# Episode 133 done after 146 steps, reward Average: -171.57, up to now: minReward: -118.0, minAverage: -171.57
# Episode 134 done after 120 steps, reward Average: -171.15, up to now: minReward: -118.0, minAverage: -171.15
# Episode 135 done after 126 steps, reward Average: -170.41, up to now: minReward: -118.0, minAverage: -170.41
# Episode 136 done after 162 steps, reward Average: -170.03, up to now: minReward: -118.0, minAverage: -170.03
# Episode 137 done after 145 steps, reward Average: -169.48, up to now: minReward: -118.0, minAverage: -169.48
# Episode 138 done after 147 steps, reward Average: -168.95, up to now: minReward: -118.0, minAverage: -168.95
# Episode 139 done after 123 steps, reward Average: -168.18, up to now: minReward: -118.0, minAverage: -168.18
# Episode 140 done after 149 steps, reward Average: -168.02, up to now: minReward: -118.0, minAverage: -168.02
# Episode 141 done after 115 steps, reward Average: -167.17, up to now: minReward: -115.0, minAverage: -167.17
# Episode 142 done after 118 steps, reward Average: -166.75, up to now: minReward: -115.0, minAverage: -166.75
# Episode 143 done after 149 steps, reward Average: -166.24, up to now: minReward: -115.0, minAverage: -166.24
# Episode 144 done after 147 steps, reward Average: -165.71, up to now: minReward: -115.0, minAverage: -165.71
# Episode 145 done after 169 steps, reward Average: -165.4, up to now: minReward: -115.0, minAverage: -165.4
# Episode 146 done after 137 steps, reward Average: -164.77, up to now: minReward: -115.0, minAverage: -164.77
# Episode 147 done after 116 steps, reward Average: -164.14, up to now: minReward: -115.0, minAverage: -164.14
# Episode 148 done after 159 steps, reward Average: -164.14, up to now: minReward: -115.0, minAverage: -164.14
# Episode 149 done after 156 steps, reward Average: -163.7, up to now: minReward: -115.0, minAverage: -163.7
# Episode 150 done after 153 steps, reward Average: -163.23, up to now: minReward: -115.0, minAverage: -163.23
# Episode 151 done after 150 steps, reward Average: -162.73, up to now: minReward: -115.0, minAverage: -162.73
# Episode 152 done after 149 steps, reward Average: -162.22, up to now: minReward: -115.0, minAverage: -162.22
# Episode 153 done after 116 steps, reward Average: -161.38, up to now: minReward: -115.0, minAverage: -161.38
# Episode 154 done after 116 steps, reward Average: -160.54, up to now: minReward: -115.0, minAverage: -160.54
# Episode 155 done after 114 steps, reward Average: -159.68, up to now: minReward: -114.0, minAverage: -159.68
# Episode 156 done after 153 steps, reward Average: -159.21, up to now: minReward: -114.0, minAverage: -159.21
# Episode 157 done after 114 steps, reward Average: -158.39, up to now: minReward: -114.0, minAverage: -158.39
# Episode 158 done after 155 steps, reward Average: -157.94, up to now: minReward: -114.0, minAverage: -157.94
# Episode 159 done after 160 steps, reward Average: -157.54, up to now: minReward: -114.0, minAverage: -157.54
# Episode 160 done after 136 steps, reward Average: -157.37, up to now: minReward: -114.0, minAverage: -157.37
# Episode 161 done after 116 steps, reward Average: -156.91, up to now: minReward: -114.0, minAverage: -156.91
# Episode 162 done after 118 steps, reward Average: -156.09, up to now: minReward: -114.0, minAverage: -156.09
# Episode 163 done after 157 steps, reward Average: -155.66, up to now: minReward: -114.0, minAverage: -155.66
# Episode 164 done after 148 steps, reward Average: -155.4, up to now: minReward: -114.0, minAverage: -155.4
# Episode 165 done after 134 steps, reward Average: -154.79, up to now: minReward: -114.0, minAverage: -154.79
# Episode 166 done after 127 steps, reward Average: -154.46, up to now: minReward: -114.0, minAverage: -154.46
# Episode 167 done after 152 steps, reward Average: -154.07, up to now: minReward: -114.0, minAverage: -154.07
# Episode 168 done after 124 steps, reward Average: -153.78, up to now: minReward: -114.0, minAverage: -153.78
# Episode 169 done after 156 steps, reward Average: -153.75, up to now: minReward: -114.0, minAverage: -153.75
# Episode 170 done after 150 steps, reward Average: -153.25, up to now: minReward: -114.0, minAverage: -153.25
# Episode 171 done after 145 steps, reward Average: -153.05, up to now: minReward: -114.0, minAverage: -153.05
# Episode 172 done after 163 steps, reward Average: -153.14, up to now: minReward: -114.0, minAverage: -153.05
# Episode 173 done after 146 steps, reward Average: -153.05, up to now: minReward: -114.0, minAverage: -153.05
# Episode 174 done after 147 steps, reward Average: -152.95, up to now: minReward: -114.0, minAverage: -152.95
# Episode 175 done after 139 steps, reward Average: -152.81, up to now: minReward: -114.0, minAverage: -152.81
# Episode 176 done after 155 steps, reward Average: -153.08, up to now: minReward: -114.0, minAverage: -152.81
# Episode 177 done after 136 steps, reward Average: -152.44, up to now: minReward: -114.0, minAverage: -152.44
# Episode 178 done after 119 steps, reward Average: -151.99, up to now: minReward: -114.0, minAverage: -151.99
# Episode 179 done after 121 steps, reward Average: -151.2, up to now: minReward: -114.0, minAverage: -151.2
# Episode 180 done after 116 steps, reward Average: -150.72, up to now: minReward: -114.0, minAverage: -150.72
# Episode 181 done after 157 steps, reward Average: -150.67, up to now: minReward: -114.0, minAverage: -150.67
# Episode 182 done after 125 steps, reward Average: -150.33, up to now: minReward: -114.0, minAverage: -150.33
# Episode 183 done after 124 steps, reward Average: -149.57, up to now: minReward: -114.0, minAverage: -149.57
# Episode 184 done after 161 steps, reward Average: -149.29, up to now: minReward: -114.0, minAverage: -149.29
# Episode 185 done after 160 steps, reward Average: -149.67, up to now: minReward: -114.0, minAverage: -149.29
# Episode 186 done after 124 steps, reward Average: -148.91, up to now: minReward: -114.0, minAverage: -148.91
# Episode 187 done after 152 steps, reward Average: -148.43, up to now: minReward: -114.0, minAverage: -148.43
# Episode 188 done after 152 steps, reward Average: -148.24, up to now: minReward: -114.0, minAverage: -148.24
# Episode 189 done after 157 steps, reward Average: -148.27, up to now: minReward: -114.0, minAverage: -148.24
# Episode 190 done after 155 steps, reward Average: -148.27, up to now: minReward: -114.0, minAverage: -148.24
# Episode 191 done after 157 steps, reward Average: -148.28, up to now: minReward: -114.0, minAverage: -148.24
# Episode 192 done after 149 steps, reward Average: -148.2, up to now: minReward: -114.0, minAverage: -148.2
# Episode 193 done after 154 steps, reward Average: -147.74, up to now: minReward: -114.0, minAverage: -147.74
# Episode 194 done after 130 steps, reward Average: -147.65, up to now: minReward: -114.0, minAverage: -147.65
# Episode 195 done after 159 steps, reward Average: -147.31, up to now: minReward: -114.0, minAverage: -147.31
# Episode 196 done after 161 steps, reward Average: -147.08, up to now: minReward: -114.0, minAverage: -147.08
# Episode 197 done after 159 steps, reward Average: -146.81, up to now: minReward: -114.0, minAverage: -146.81
# Episode 198 done after 154 steps, reward Average: -147.1, up to now: minReward: -114.0, minAverage: -146.81
# Episode 199 done after 145 steps, reward Average: -146.82, up to now: minReward: -114.0, minAverage: -146.81
# Episode 200 done after 127 steps, reward Average: -146.19, up to now: minReward: -114.0, minAverage: -146.19
# Episode 201 done after 162 steps, reward Average: -146.62, up to now: minReward: -114.0, minAverage: -146.19
# Episode 202 done after 152 steps, reward Average: -146.71, up to now: minReward: -114.0, minAverage: -146.19
# Episode 203 done after 154 steps, reward Average: -146.38, up to now: minReward: -114.0, minAverage: -146.19
# Episode 204 done after 158 steps, reward Average: -146.51, up to now: minReward: -114.0, minAverage: -146.19
# Episode 205 done after 157 steps, reward Average: -146.56, up to now: minReward: -114.0, minAverage: -146.19
# Episode 206 done after 148 steps, reward Average: -146.59, up to now: minReward: -114.0, minAverage: -146.19
# Episode 207 done after 150 steps, reward Average: -146.87, up to now: minReward: -114.0, minAverage: -146.19
# Episode 208 done after 131 steps, reward Average: -146.63, up to now: minReward: -114.0, minAverage: -146.19
# Episode 209 done after 115 steps, reward Average: -145.86, up to now: minReward: -114.0, minAverage: -145.86
# Episode 210 done after 151 steps, reward Average: -146.16, up to now: minReward: -114.0, minAverage: -145.86
# Episode 211 done after 156 steps, reward Average: -145.72, up to now: minReward: -114.0, minAverage: -145.72
# Episode 212 done after 151 steps, reward Average: -145.6, up to now: minReward: -114.0, minAverage: -145.6
# Episode 213 done after 155 steps, reward Average: -145.23, up to now: minReward: -114.0, minAverage: -145.23
# Episode 214 done after 150 steps, reward Average: -144.77, up to now: minReward: -114.0, minAverage: -144.77
# Episode 215 done after 157 steps, reward Average: -145.11, up to now: minReward: -114.0, minAverage: -144.77
# Episode 216 done after 151 steps, reward Average: -145.01, up to now: minReward: -114.0, minAverage: -144.77
# Episode 217 done after 150 steps, reward Average: -144.54, up to now: minReward: -114.0, minAverage: -144.54
# Episode 218 done after 146 steps, reward Average: -144.78, up to now: minReward: -114.0, minAverage: -144.54
# Episode 219 done after 194 steps, reward Average: -145.54, up to now: minReward: -114.0, minAverage: -144.54
# Episode 220 done after 122 steps, reward Average: -145.36, up to now: minReward: -114.0, minAverage: -144.54
# Episode 221 done after 153 steps, reward Average: -144.89, up to now: minReward: -114.0, minAverage: -144.54
# Episode 222 done after 113 steps, reward Average: -144.22, up to now: minReward: -113.0, minAverage: -144.22
# Episode 223 done after 115 steps, reward Average: -144.1, up to now: minReward: -113.0, minAverage: -144.1
# Episode 224 done after 115 steps, reward Average: -143.7, up to now: minReward: -113.0, minAverage: -143.7
# Episode 225 done after 152 steps, reward Average: -144.01, up to now: minReward: -113.0, minAverage: -143.7
# Episode 226 done after 115 steps, reward Average: -143.16, up to now: minReward: -113.0, minAverage: -143.16
# Episode 227 done after 112 steps, reward Average: -142.71, up to now: minReward: -112.0, minAverage: -142.71
# Episode 228 done after 159 steps, reward Average: -142.8, up to now: minReward: -112.0, minAverage: -142.71
# Episode 229 done after 153 steps, reward Average: -142.78, up to now: minReward: -112.0, minAverage: -142.71
# Episode 230 done after 156 steps, reward Average: -142.83, up to now: minReward: -112.0, minAverage: -142.71
# Episode 231 done after 145 steps, reward Average: -142.83, up to now: minReward: -112.0, minAverage: -142.71
# Episode 232 done after 151 steps, reward Average: -142.8, up to now: minReward: -112.0, minAverage: -142.71
# Episode 233 done after 155 steps, reward Average: -142.89, up to now: minReward: -112.0, minAverage: -142.71
# Episode 234 done after 152 steps, reward Average: -143.21, up to now: minReward: -112.0, minAverage: -142.71
# Episode 235 done after 152 steps, reward Average: -143.47, up to now: minReward: -112.0, minAverage: -142.71
# Episode 236 done after 154 steps, reward Average: -143.39, up to now: minReward: -112.0, minAverage: -142.71
# Episode 237 done after 142 steps, reward Average: -143.36, up to now: minReward: -112.0, minAverage: -142.71
# Episode 238 done after 160 steps, reward Average: -143.49, up to now: minReward: -112.0, minAverage: -142.71
# Episode 239 done after 142 steps, reward Average: -143.68, up to now: minReward: -112.0, minAverage: -142.71
# Episode 240 done after 149 steps, reward Average: -143.68, up to now: minReward: -112.0, minAverage: -142.71
# Episode 241 done after 150 steps, reward Average: -144.03, up to now: minReward: -112.0, minAverage: -142.71
# Episode 242 done after 155 steps, reward Average: -144.4, up to now: minReward: -112.0, minAverage: -142.71
# Episode 243 done after 147 steps, reward Average: -144.38, up to now: minReward: -112.0, minAverage: -142.71
# Episode 244 done after 160 steps, reward Average: -144.51, up to now: minReward: -112.0, minAverage: -142.71
# Episode 245 done after 124 steps, reward Average: -144.06, up to now: minReward: -112.0, minAverage: -142.71
# Episode 246 done after 158 steps, reward Average: -144.27, up to now: minReward: -112.0, minAverage: -142.71
# Episode 247 done after 166 steps, reward Average: -144.77, up to now: minReward: -112.0, minAverage: -142.71
# Episode 248 done after 151 steps, reward Average: -144.69, up to now: minReward: -112.0, minAverage: -142.71
# Episode 249 done after 145 steps, reward Average: -144.58, up to now: minReward: -112.0, minAverage: -142.71
# Episode 250 done after 146 steps, reward Average: -144.51, up to now: minReward: -112.0, minAverage: -142.71
# Episode 251 done after 120 steps, reward Average: -144.21, up to now: minReward: -112.0, minAverage: -142.71
# Episode 252 done after 116 steps, reward Average: -143.88, up to now: minReward: -112.0, minAverage: -142.71
# Episode 253 done after 121 steps, reward Average: -143.93, up to now: minReward: -112.0, minAverage: -142.71
# Episode 254 done after 160 steps, reward Average: -144.37, up to now: minReward: -112.0, minAverage: -142.71
# Episode 255 done after 146 steps, reward Average: -144.69, up to now: minReward: -112.0, minAverage: -142.71
# Episode 256 done after 121 steps, reward Average: -144.37, up to now: minReward: -112.0, minAverage: -142.71
# Episode 257 done after 112 steps, reward Average: -144.35, up to now: minReward: -112.0, minAverage: -142.71
# Episode 258 done after 156 steps, reward Average: -144.36, up to now: minReward: -112.0, minAverage: -142.71
# Episode 259 done after 150 steps, reward Average: -144.26, up to now: minReward: -112.0, minAverage: -142.71
# Episode 260 done after 115 steps, reward Average: -144.05, up to now: minReward: -112.0, minAverage: -142.71
# Episode 261 done after 150 steps, reward Average: -144.39, up to now: minReward: -112.0, minAverage: -142.71
# Episode 262 done after 129 steps, reward Average: -144.5, up to now: minReward: -112.0, minAverage: -142.71
# Episode 263 done after 187 steps, reward Average: -144.8, up to now: minReward: -112.0, minAverage: -142.71
# Episode 264 done after 156 steps, reward Average: -144.88, up to now: minReward: -112.0, minAverage: -142.71
# Episode 265 done after 161 steps, reward Average: -145.15, up to now: minReward: -112.0, minAverage: -142.71
# Episode 266 done after 117 steps, reward Average: -145.05, up to now: minReward: -112.0, minAverage: -142.71
# Episode 267 done after 157 steps, reward Average: -145.1, up to now: minReward: -112.0, minAverage: -142.71
# Episode 268 done after 147 steps, reward Average: -145.33, up to now: minReward: -112.0, minAverage: -142.71
# Episode 269 done after 140 steps, reward Average: -145.17, up to now: minReward: -112.0, minAverage: -142.71
# Episode 270 done after 150 steps, reward Average: -145.17, up to now: minReward: -112.0, minAverage: -142.71
# Episode 271 done after 129 steps, reward Average: -145.01, up to now: minReward: -112.0, minAverage: -142.71
# Episode 272 done after 160 steps, reward Average: -144.98, up to now: minReward: -112.0, minAverage: -142.71
# Episode 273 done after 152 steps, reward Average: -145.04, up to now: minReward: -112.0, minAverage: -142.71
# Episode 274 done after 200 steps, reward Average: -145.57, up to now: minReward: -112.0, minAverage: -142.71
# Episode 275 done after 154 steps, reward Average: -145.72, up to now: minReward: -112.0, minAverage: -142.71
# Episode 276 done after 147 steps, reward Average: -145.64, up to now: minReward: -112.0, minAverage: -142.71
# Episode 277 done after 148 steps, reward Average: -145.76, up to now: minReward: -112.0, minAverage: -142.71
# Episode 278 done after 150 steps, reward Average: -146.07, up to now: minReward: -112.0, minAverage: -142.71
# Episode 279 done after 139 steps, reward Average: -146.25, up to now: minReward: -112.0, minAverage: -142.71
# Episode 280 done after 114 steps, reward Average: -146.23, up to now: minReward: -112.0, minAverage: -142.71
# Episode 281 done after 118 steps, reward Average: -145.84, up to now: minReward: -112.0, minAverage: -142.71
# Episode 282 done after 111 steps, reward Average: -145.7, up to now: minReward: -111.0, minAverage: -142.71
# Episode 283 done after 125 steps, reward Average: -145.71, up to now: minReward: -111.0, minAverage: -142.71
# Episode 284 done after 113 steps, reward Average: -145.23, up to now: minReward: -111.0, minAverage: -142.71
# Episode 285 done after 169 steps, reward Average: -145.32, up to now: minReward: -111.0, minAverage: -142.71
# Episode 286 done after 147 steps, reward Average: -145.55, up to now: minReward: -111.0, minAverage: -142.71
# Episode 287 done after 165 steps, reward Average: -145.68, up to now: minReward: -111.0, minAverage: -142.71
# Episode 288 done after 149 steps, reward Average: -145.65, up to now: minReward: -111.0, minAverage: -142.71
# Episode 289 done after 157 steps, reward Average: -145.65, up to now: minReward: -111.0, minAverage: -142.71
# Episode 290 done after 161 steps, reward Average: -145.71, up to now: minReward: -111.0, minAverage: -142.71
# Episode 291 done after 146 steps, reward Average: -145.6, up to now: minReward: -111.0, minAverage: -142.71
# Episode 292 done after 116 steps, reward Average: -145.27, up to now: minReward: -111.0, minAverage: -142.71
# Episode 293 done after 160 steps, reward Average: -145.33, up to now: minReward: -111.0, minAverage: -142.71
# Episode 294 done after 156 steps, reward Average: -145.59, up to now: minReward: -111.0, minAverage: -142.71
# Episode 295 done after 159 steps, reward Average: -145.59, up to now: minReward: -111.0, minAverage: -142.71
# Episode 296 done after 146 steps, reward Average: -145.44, up to now: minReward: -111.0, minAverage: -142.71
# Episode 297 done after 117 steps, reward Average: -145.02, up to now: minReward: -111.0, minAverage: -142.71
# Episode 298 done after 160 steps, reward Average: -145.08, up to now: minReward: -111.0, minAverage: -142.71
# Episode 299 done after 157 steps, reward Average: -145.2, up to now: minReward: -111.0, minAverage: -142.71
# Episode 300 done after 153 steps, reward Average: -145.46, up to now: minReward: -111.0, minAverage: -142.71
# Episode 301 done after 148 steps, reward Average: -145.32, up to now: minReward: -111.0, minAverage: -142.71
# Episode 302 done after 149 steps, reward Average: -145.29, up to now: minReward: -111.0, minAverage: -142.71
# Episode 303 done after 115 steps, reward Average: -144.9, up to now: minReward: -111.0, minAverage: -142.71
# Episode 304 done after 150 steps, reward Average: -144.82, up to now: minReward: -111.0, minAverage: -142.71
# Episode 305 done after 148 steps, reward Average: -144.73, up to now: minReward: -111.0, minAverage: -142.71
# Episode 306 done after 146 steps, reward Average: -144.71, up to now: minReward: -111.0, minAverage: -142.71
# Episode 307 done after 143 steps, reward Average: -144.64, up to now: minReward: -111.0, minAverage: -142.71
# Episode 308 done after 152 steps, reward Average: -144.85, up to now: minReward: -111.0, minAverage: -142.71
# Episode 309 done after 152 steps, reward Average: -145.22, up to now: minReward: -111.0, minAverage: -142.71
# Episode 310 done after 116 steps, reward Average: -144.87, up to now: minReward: -111.0, minAverage: -142.71
# Episode 311 done after 117 steps, reward Average: -144.48, up to now: minReward: -111.0, minAverage: -142.71
# Episode 312 done after 149 steps, reward Average: -144.46, up to now: minReward: -111.0, minAverage: -142.71
# Episode 313 done after 123 steps, reward Average: -144.14, up to now: minReward: -111.0, minAverage: -142.71
# Episode 314 done after 146 steps, reward Average: -144.1, up to now: minReward: -111.0, minAverage: -142.71
# Episode 315 done after 147 steps, reward Average: -144.0, up to now: minReward: -111.0, minAverage: -142.71
# Episode 316 done after 148 steps, reward Average: -143.97, up to now: minReward: -111.0, minAverage: -142.71
# Episode 317 done after 149 steps, reward Average: -143.96, up to now: minReward: -111.0, minAverage: -142.71
# Episode 318 done after 153 steps, reward Average: -144.03, up to now: minReward: -111.0, minAverage: -142.71
# Episode 319 done after 147 steps, reward Average: -143.56, up to now: minReward: -111.0, minAverage: -142.71
# Episode 320 done after 120 steps, reward Average: -143.54, up to now: minReward: -111.0, minAverage: -142.71
# Episode 321 done after 153 steps, reward Average: -143.54, up to now: minReward: -111.0, minAverage: -142.71
# Episode 322 done after 126 steps, reward Average: -143.67, up to now: minReward: -111.0, minAverage: -142.71
# Episode 323 done after 147 steps, reward Average: -143.99, up to now: minReward: -111.0, minAverage: -142.71
# Episode 324 done after 152 steps, reward Average: -144.36, up to now: minReward: -111.0, minAverage: -142.71
# Episode 325 done after 144 steps, reward Average: -144.28, up to now: minReward: -111.0, minAverage: -142.71
# Episode 326 done after 151 steps, reward Average: -144.64, up to now: minReward: -111.0, minAverage: -142.71
# Episode 327 done after 156 steps, reward Average: -145.08, up to now: minReward: -111.0, minAverage: -142.71
# Episode 328 done after 124 steps, reward Average: -144.73, up to now: minReward: -111.0, minAverage: -142.71
# Episode 329 done after 160 steps, reward Average: -144.8, up to now: minReward: -111.0, minAverage: -142.71
# Episode 330 done after 159 steps, reward Average: -144.83, up to now: minReward: -111.0, minAverage: -142.71
# Episode 331 done after 109 steps, reward Average: -144.47, up to now: minReward: -109.0, minAverage: -142.71
# Episode 332 done after 166 steps, reward Average: -144.62, up to now: minReward: -109.0, minAverage: -142.71
# Episode 333 done after 116 steps, reward Average: -144.23, up to now: minReward: -109.0, minAverage: -142.71
# Episode 334 done after 113 steps, reward Average: -143.84, up to now: minReward: -109.0, minAverage: -142.71
# Episode 335 done after 120 steps, reward Average: -143.52, up to now: minReward: -109.0, minAverage: -142.71
# Episode 336 done after 162 steps, reward Average: -143.6, up to now: minReward: -109.0, minAverage: -142.71
# Episode 337 done after 159 steps, reward Average: -143.77, up to now: minReward: -109.0, minAverage: -142.71
# Episode 338 done after 146 steps, reward Average: -143.63, up to now: minReward: -109.0, minAverage: -142.71
# Episode 339 done after 165 steps, reward Average: -143.86, up to now: minReward: -109.0, minAverage: -142.71
# Episode 340 done after 128 steps, reward Average: -143.65, up to now: minReward: -109.0, minAverage: -142.71
# Episode 341 done after 152 steps, reward Average: -143.67, up to now: minReward: -109.0, minAverage: -142.71
# Episode 342 done after 110 steps, reward Average: -143.22, up to now: minReward: -109.0, minAverage: -142.71
# Episode 343 done after 115 steps, reward Average: -142.9, up to now: minReward: -109.0, minAverage: -142.71
# Episode 344 done after 149 steps, reward Average: -142.79, up to now: minReward: -109.0, minAverage: -142.71
# Episode 345 done after 154 steps, reward Average: -143.09, up to now: minReward: -109.0, minAverage: -142.71
# Episode 346 done after 115 steps, reward Average: -142.66, up to now: minReward: -109.0, minAverage: -142.66
# Episode 347 done after 154 steps, reward Average: -142.54, up to now: minReward: -109.0, minAverage: -142.54
# Episode 348 done after 159 steps, reward Average: -142.62, up to now: minReward: -109.0, minAverage: -142.54
# Episode 349 done after 116 steps, reward Average: -142.33, up to now: minReward: -109.0, minAverage: -142.33
# Episode 350 done after 113 steps, reward Average: -142.0, up to now: minReward: -109.0, minAverage: -142.0
# Episode 351 done after 118 steps, reward Average: -141.98, up to now: minReward: -109.0, minAverage: -141.98
# Episode 352 done after 122 steps, reward Average: -142.04, up to now: minReward: -109.0, minAverage: -141.98
# Episode 353 done after 112 steps, reward Average: -141.95, up to now: minReward: -109.0, minAverage: -141.95
# Episode 354 done after 108 steps, reward Average: -141.43, up to now: minReward: -108.0, minAverage: -141.43
# Episode 355 done after 115 steps, reward Average: -141.12, up to now: minReward: -108.0, minAverage: -141.12
# Episode 356 done after 115 steps, reward Average: -141.06, up to now: minReward: -108.0, minAverage: -141.06
# Episode 357 done after 113 steps, reward Average: -141.07, up to now: minReward: -108.0, minAverage: -141.06
# Episode 358 done after 165 steps, reward Average: -141.16, up to now: minReward: -108.0, minAverage: -141.06
# Episode 359 done after 150 steps, reward Average: -141.16, up to now: minReward: -108.0, minAverage: -141.06
# Episode 360 done after 165 steps, reward Average: -141.66, up to now: minReward: -108.0, minAverage: -141.06
# Episode 361 done after 114 steps, reward Average: -141.3, up to now: minReward: -108.0, minAverage: -141.06
# Episode 362 done after 147 steps, reward Average: -141.48, up to now: minReward: -108.0, minAverage: -141.06
# Episode 363 done after 152 steps, reward Average: -141.13, up to now: minReward: -108.0, minAverage: -141.06
# Episode 364 done after 147 steps, reward Average: -141.04, up to now: minReward: -108.0, minAverage: -141.04
# Episode 365 done after 149 steps, reward Average: -140.92, up to now: minReward: -108.0, minAverage: -140.92
# Episode 366 done after 152 steps, reward Average: -141.27, up to now: minReward: -108.0, minAverage: -140.92
# Episode 367 done after 148 steps, reward Average: -141.18, up to now: minReward: -108.0, minAverage: -140.92
# Episode 368 done after 152 steps, reward Average: -141.23, up to now: minReward: -108.0, minAverage: -140.92
# Episode 369 done after 148 steps, reward Average: -141.31, up to now: minReward: -108.0, minAverage: -140.92
# Episode 370 done after 125 steps, reward Average: -141.06, up to now: minReward: -108.0, minAverage: -140.92
# Episode 371 done after 118 steps, reward Average: -140.95, up to now: minReward: -108.0, minAverage: -140.92
# Episode 372 done after 114 steps, reward Average: -140.49, up to now: minReward: -108.0, minAverage: -140.49
# Episode 373 done after 159 steps, reward Average: -140.56, up to now: minReward: -108.0, minAverage: -140.49
# Episode 374 done after 151 steps, reward Average: -140.07, up to now: minReward: -108.0, minAverage: -140.07
# Episode 375 done after 174 steps, reward Average: -140.27, up to now: minReward: -108.0, minAverage: -140.07
# Episode 376 done after 149 steps, reward Average: -140.29, up to now: minReward: -108.0, minAverage: -140.07
# Episode 377 done after 153 steps, reward Average: -140.34, up to now: minReward: -108.0, minAverage: -140.07
# Episode 378 done after 111 steps, reward Average: -139.95, up to now: minReward: -108.0, minAverage: -139.95
# Episode 379 done after 152 steps, reward Average: -140.08, up to now: minReward: -108.0, minAverage: -139.95
# Episode 380 done after 150 steps, reward Average: -140.44, up to now: minReward: -108.0, minAverage: -139.95
# Episode 381 done after 112 steps, reward Average: -140.38, up to now: minReward: -108.0, minAverage: -139.95
# Episode 382 done after 107 steps, reward Average: -140.34, up to now: minReward: -107.0, minAverage: -139.95
# Episode 383 done after 146 steps, reward Average: -140.55, up to now: minReward: -107.0, minAverage: -139.95
# Episode 384 done after 116 steps, reward Average: -140.58, up to now: minReward: -107.0, minAverage: -139.95
# Episode 385 done after 143 steps, reward Average: -140.32, up to now: minReward: -107.0, minAverage: -139.95
# Episode 386 done after 155 steps, reward Average: -140.4, up to now: minReward: -107.0, minAverage: -139.95
# Episode 387 done after 145 steps, reward Average: -140.2, up to now: minReward: -107.0, minAverage: -139.95
# Episode 388 done after 157 steps, reward Average: -140.28, up to now: minReward: -107.0, minAverage: -139.95
# Episode 389 done after 148 steps, reward Average: -140.19, up to now: minReward: -107.0, minAverage: -139.95
# Episode 390 done after 151 steps, reward Average: -140.09, up to now: minReward: -107.0, minAverage: -139.95
# Episode 391 done after 146 steps, reward Average: -140.09, up to now: minReward: -107.0, minAverage: -139.95
# Episode 392 done after 143 steps, reward Average: -140.36, up to now: minReward: -107.0, minAverage: -139.95
# Episode 393 done after 149 steps, reward Average: -140.25, up to now: minReward: -107.0, minAverage: -139.95
# Episode 394 done after 144 steps, reward Average: -140.13, up to now: minReward: -107.0, minAverage: -139.95
# Episode 395 done after 148 steps, reward Average: -140.02, up to now: minReward: -107.0, minAverage: -139.95
# Episode 396 done after 148 steps, reward Average: -140.04, up to now: minReward: -107.0, minAverage: -139.95
# Episode 397 done after 148 steps, reward Average: -140.35, up to now: minReward: -107.0, minAverage: -139.95
# Episode 398 done after 143 steps, reward Average: -140.18, up to now: minReward: -107.0, minAverage: -139.95
# Episode 399 done after 148 steps, reward Average: -140.09, up to now: minReward: -107.0, minAverage: -139.95
# Episode 400 done after 148 steps, reward Average: -140.04, up to now: minReward: -107.0, minAverage: -139.95
# Episode 401 done after 148 steps, reward Average: -140.04, up to now: minReward: -107.0, minAverage: -139.95
# Episode 402 done after 149 steps, reward Average: -140.04, up to now: minReward: -107.0, minAverage: -139.95
# Episode 403 done after 146 steps, reward Average: -140.35, up to now: minReward: -107.0, minAverage: -139.95
# Episode 404 done after 153 steps, reward Average: -140.38, up to now: minReward: -107.0, minAverage: -139.95
# Episode 405 done after 148 steps, reward Average: -140.38, up to now: minReward: -107.0, minAverage: -139.95
# Episode 406 done after 157 steps, reward Average: -140.49, up to now: minReward: -107.0, minAverage: -139.95
# Episode 407 done after 141 steps, reward Average: -140.47, up to now: minReward: -107.0, minAverage: -139.95
# Episode 408 done after 156 steps, reward Average: -140.51, up to now: minReward: -107.0, minAverage: -139.95
# Episode 409 done after 147 steps, reward Average: -140.46, up to now: minReward: -107.0, minAverage: -139.95
# Episode 410 done after 151 steps, reward Average: -140.81, up to now: minReward: -107.0, minAverage: -139.95
# Episode 411 done after 122 steps, reward Average: -140.86, up to now: minReward: -107.0, minAverage: -139.95
# Episode 412 done after 157 steps, reward Average: -140.94, up to now: minReward: -107.0, minAverage: -139.95
# Episode 413 done after 163 steps, reward Average: -141.34, up to now: minReward: -107.0, minAverage: -139.95
# Episode 414 done after 153 steps, reward Average: -141.41, up to now: minReward: -107.0, minAverage: -139.95
# Episode 415 done after 148 steps, reward Average: -141.42, up to now: minReward: -107.0, minAverage: -139.95
# Episode 416 done after 150 steps, reward Average: -141.44, up to now: minReward: -107.0, minAverage: -139.95
# Episode 417 done after 146 steps, reward Average: -141.41, up to now: minReward: -107.0, minAverage: -139.95
# Episode 418 done after 115 steps, reward Average: -141.03, up to now: minReward: -107.0, minAverage: -139.95
# Episode 419 done after 151 steps, reward Average: -141.07, up to now: minReward: -107.0, minAverage: -139.95
# Episode 420 done after 146 steps, reward Average: -141.33, up to now: minReward: -107.0, minAverage: -139.95
# Episode 421 done after 134 steps, reward Average: -141.14, up to now: minReward: -107.0, minAverage: -139.95
# Episode 422 done after 113 steps, reward Average: -141.01, up to now: minReward: -107.0, minAverage: -139.95
# Episode 423 done after 114 steps, reward Average: -140.68, up to now: minReward: -107.0, minAverage: -139.95
# Episode 424 done after 142 steps, reward Average: -140.58, up to now: minReward: -107.0, minAverage: -139.95
# Episode 425 done after 148 steps, reward Average: -140.62, up to now: minReward: -107.0, minAverage: -139.95
# ...
# Episode 9854 done after 159 steps, reward Average: -121.14, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9855 done after 131 steps, reward Average: -120.88, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9856 done after 118 steps, reward Average: -120.9, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9857 done after 97 steps, reward Average: -120.37, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9858 done after 113 steps, reward Average: -120.54, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9859 done after 113 steps, reward Average: -120.55, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9860 done after 114 steps, reward Average: -120.57, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9861 done after 92 steps, reward Average: -120.37, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9862 done after 95 steps, reward Average: -119.65, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9863 done after 102 steps, reward Average: -119.13, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9864 done after 102 steps, reward Average: -119.12, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9865 done after 109 steps, reward Average: -119.07, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9866 done after 113 steps, reward Average: -119.01, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9867 done after 95 steps, reward Average: -118.85, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9868 done after 112 steps, reward Average: -118.28, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9869 done after 110 steps, reward Average: -118.28, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9870 done after 102 steps, reward Average: -118.21, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9871 done after 94 steps, reward Average: -118.13, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9872 done after 112 steps, reward Average: -118.29, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9873 done after 161 steps, reward Average: -118.78, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9874 done after 112 steps, reward Average: -118.75, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9875 done after 110 steps, reward Average: -118.74, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9876 done after 150 steps, reward Average: -119.02, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9877 done after 109 steps, reward Average: -118.62, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9878 done after 115 steps, reward Average: -118.65, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9879 done after 95 steps, reward Average: -118.46, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9880 done after 109 steps, reward Average: -118.42, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9881 done after 167 steps, reward Average: -118.56, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9882 done after 185 steps, reward Average: -119.46, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9883 done after 117 steps, reward Average: -119.51, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9884 done after 93 steps, reward Average: -119.3, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9885 done after 91 steps, reward Average: -119.09, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9886 done after 103 steps, reward Average: -119.01, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9887 done after 146 steps, reward Average: -119.32, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9888 done after 95 steps, reward Average: -119.15, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9889 done after 113 steps, reward Average: -119.11, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9890 done after 177 steps, reward Average: -119.77, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9891 done after 156 steps, reward Average: -120.17, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9892 done after 116 steps, reward Average: -120.2, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9893 done after 115 steps, reward Average: -120.2, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9894 done after 144 steps, reward Average: -120.51, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9895 done after 153 steps, reward Average: -121.1, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9896 done after 111 steps, reward Average: -120.54, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9897 done after 127 steps, reward Average: -120.21, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9898 done after 174 steps, reward Average: -120.83, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9899 done after 110 steps, reward Average: -120.78, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9900 done after 100 steps, reward Average: -120.75, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9901 done after 121 steps, reward Average: -120.73, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9902 done after 110 steps, reward Average: -120.74, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9903 done after 111 steps, reward Average: -120.72, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9904 done after 107 steps, reward Average: -120.66, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9905 done after 112 steps, reward Average: -120.6, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9906 done after 97 steps, reward Average: -120.61, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9907 done after 157 steps, reward Average: -121.04, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9908 done after 111 steps, reward Average: -121.05, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9909 done after 97 steps, reward Average: -120.37, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9910 done after 110 steps, reward Average: -120.37, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9911 done after 156 steps, reward Average: -120.83, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9912 done after 112 steps, reward Average: -120.19, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9913 done after 111 steps, reward Average: -120.11, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9914 done after 110 steps, reward Average: -120.24, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9915 done after 111 steps, reward Average: -120.16, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9916 done after 111 steps, reward Average: -120.36, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9917 done after 92 steps, reward Average: -120.31, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9918 done after 113 steps, reward Average: -119.92, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9919 done after 112 steps, reward Average: -119.94, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9920 done after 98 steps, reward Average: -119.38, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9921 done after 115 steps, reward Average: -119.58, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9922 done after 109 steps, reward Average: -119.69, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9923 done after 109 steps, reward Average: -119.63, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9924 done after 152 steps, reward Average: -120.16, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9925 done after 115 steps, reward Average: -119.82, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9926 done after 97 steps, reward Average: -119.26, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9927 done after 115 steps, reward Average: -119.0, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9928 done after 111 steps, reward Average: -118.94, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9929 done after 96 steps, reward Average: -118.45, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9930 done after 92 steps, reward Average: -118.26, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9931 done after 163 steps, reward Average: -118.79, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9932 done after 112 steps, reward Average: -118.79, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9933 done after 113 steps, reward Average: -118.48, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9934 done after 90 steps, reward Average: -117.97, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9935 done after 117 steps, reward Average: -117.64, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9936 done after 160 steps, reward Average: -118.12, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9937 done after 98 steps, reward Average: -117.33, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9938 done after 115 steps, reward Average: -117.4, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9939 done after 111 steps, reward Average: -117.31, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9940 done after 92 steps, reward Average: -116.62, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9941 done after 96 steps, reward Average: -116.44, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9942 done after 114 steps, reward Average: -116.48, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9943 done after 115 steps, reward Average: -116.54, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9944 done after 114 steps, reward Average: -116.54, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9945 done after 112 steps, reward Average: -116.56, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9946 done after 93 steps, reward Average: -116.52, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9947 done after 112 steps, reward Average: -116.54, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9948 done after 112 steps, reward Average: -116.09, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9949 done after 152 steps, reward Average: -116.5, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9950 done after 161 steps, reward Average: -116.98, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9951 done after 120 steps, reward Average: -117.06, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9952 done after 96 steps, reward Average: -116.9, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9953 done after 154 steps, reward Average: -117.29, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9954 done after 159 steps, reward Average: -117.29, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9955 done after 115 steps, reward Average: -117.13, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9956 done after 156 steps, reward Average: -117.51, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9957 done after 114 steps, reward Average: -117.68, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9958 done after 149 steps, reward Average: -118.04, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9959 done after 151 steps, reward Average: -118.42, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9960 done after 146 steps, reward Average: -118.74, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9961 done after 114 steps, reward Average: -118.96, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9962 done after 151 steps, reward Average: -119.52, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9963 done after 146 steps, reward Average: -119.96, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9964 done after 112 steps, reward Average: -120.06, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9965 done after 147 steps, reward Average: -120.44, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9966 done after 153 steps, reward Average: -120.84, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9967 done after 112 steps, reward Average: -121.01, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9968 done after 149 steps, reward Average: -121.38, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9969 done after 137 steps, reward Average: -121.65, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9970 done after 113 steps, reward Average: -121.76, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9971 done after 111 steps, reward Average: -121.93, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9972 done after 112 steps, reward Average: -121.93, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9973 done after 113 steps, reward Average: -121.45, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9974 done after 156 steps, reward Average: -121.89, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9975 done after 113 steps, reward Average: -121.92, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9976 done after 113 steps, reward Average: -121.55, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9977 done after 176 steps, reward Average: -122.22, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9978 done after 121 steps, reward Average: -122.28, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9979 done after 112 steps, reward Average: -122.45, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9980 done after 115 steps, reward Average: -122.51, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9981 done after 115 steps, reward Average: -121.99, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9982 done after 161 steps, reward Average: -121.75, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9983 done after 98 steps, reward Average: -121.56, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9984 done after 116 steps, reward Average: -121.79, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9985 done after 116 steps, reward Average: -122.04, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9986 done after 118 steps, reward Average: -122.19, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9987 done after 150 steps, reward Average: -122.23, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9988 done after 102 steps, reward Average: -122.3, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9989 done after 115 steps, reward Average: -122.32, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9990 done after 147 steps, reward Average: -122.02, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9991 done after 158 steps, reward Average: -122.04, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9992 done after 148 steps, reward Average: -122.36, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9993 done after 113 steps, reward Average: -122.34, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9994 done after 114 steps, reward Average: -122.04, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9995 done after 165 steps, reward Average: -122.16, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9996 done after 115 steps, reward Average: -122.2, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9997 done after 116 steps, reward Average: -122.09, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9998 done after 143 steps, reward Average: -121.78, up to now: minReward: -84.0, minAverage: -113.14
# Episode 9999 done after 90 steps, reward Average: -121.58, up to now: minReward: -84.0, minAverage: -113.14
# final result:
# 9925 times arrived in 10000 episodes, first time in episode 17
# problem solved?:False
